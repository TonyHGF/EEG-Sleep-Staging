# %% [markdown]
# ## Introduction
# Greetings from the Kaggle bot! This is an automatically-generated kernel with starter code demonstrating how to read in the data and begin exploring. If you're inspired to dig deeper, click the blue "Fork Notebook" button at the top of this kernel to begin editing.

# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first import libraries and define functions for plotting the data using `matplotlib`. Depending on the data, not all plots will be made. (Hey, I'm just a simple kerneling bot, not a Kaggle Competitions Grandmaster!)

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# There is 0 csv file in the current version of the dataset:

# %%
for dirname, _, filenames in os.walk('../../database'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../../database\RECORDS
# ../../database\RECORDS-v1
# ../../database\SC-subjects.xls
# ../../database\SHA256SUMS.txt
# ../../database\ST-subjects.xls
# ../../database\sleep-cassette\SC4001E0-PSG.edf
# ../../database\sleep-cassette\SC4001EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4002E0-PSG.edf
# ../../database\sleep-cassette\SC4002EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4011E0-PSG.edf
# ../../database\sleep-cassette\SC4011EH-Hypnogram.edf
# ../../database\sleep-cassette\SC4012E0-PSG.edf
# ../../database\sleep-cassette\SC4012EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4021E0-PSG.edf
# ../../database\sleep-cassette\SC4021EH-Hypnogram.edf
# ../../database\sleep-cassette\SC4022E0-PSG.edf
# ../../database\sleep-cassette\SC4022EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4031E0-PSG.edf
# ../../database\sleep-cassette\SC4031EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4032E0-PSG.edf
# ../../database\sleep-cassette\SC4032EP-Hypnogram.edf
# ../../database\sleep-cassette\SC4041E0-PSG.edf
# ../../database\sleep-cassette\SC4041EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4042E0-PSG.edf
# ../../database\sleep-cassette\SC4042EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4051E0-PSG.edf
# ../../database\sleep-cassette\SC4051EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4052E0-PSG.edf
# ../../database\sleep-cassette\SC4052EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4061E0-PSG.edf
# ../../database\sleep-cassette\SC4061EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4062E0-PSG.edf
# ../../database\sleep-cassette\SC4062EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4071E0-PSG.edf
# ../../database\sleep-cassette\SC4071EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4072E0-PSG.edf
# ../../database\sleep-cassette\SC4072EH-Hypnogram.edf
# ../../database\sleep-cassette\SC4081E0-PSG.edf
# ../../database\sleep-cassette\SC4081EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4082E0-PSG.edf
# ../../database\sleep-cassette\SC4082EP-Hypnogram.edf
# ../../database\sleep-cassette\SC4091E0-PSG.edf
# ../../database\sleep-cassette\SC4091EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4092E0-PSG.edf
# ../../database\sleep-cassette\SC4092EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4101E0-PSG.edf
# ../../database\sleep-cassette\SC4101EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4102E0-PSG.edf
# ../../database\sleep-cassette\SC4102EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4111E0-PSG.edf
# ../../database\sleep-cassette\SC4111EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4112E0-PSG.edf
# ../../database\sleep-cassette\SC4112EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4121E0-PSG.edf
# ../../database\sleep-cassette\SC4121EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4122E0-PSG.edf
# ../../database\sleep-cassette\SC4122EV-Hypnogram.edf
# ../../database\sleep-cassette\SC4131E0-PSG.edf
# ../../database\sleep-cassette\SC4131EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4141E0-PSG.edf
# ../../database\sleep-cassette\SC4141EU-Hypnogram.edf
# ../../database\sleep-cassette\SC4142E0-PSG.edf
# ../../database\sleep-cassette\SC4142EU-Hypnogram.edf
# ../../database\sleep-cassette\SC4151E0-PSG.edf
# ../../database\sleep-cassette\SC4151EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4152E0-PSG.edf
# ../../database\sleep-cassette\SC4152EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4161E0-PSG.edf
# ../../database\sleep-cassette\SC4161EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4162E0-PSG.edf
# ../../database\sleep-cassette\SC4162EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4171E0-PSG.edf
# ../../database\sleep-cassette\SC4171EU-Hypnogram.edf
# ../../database\sleep-cassette\SC4172E0-PSG.edf
# ../../database\sleep-cassette\SC4172EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4181E0-PSG.edf
# ../../database\sleep-cassette\SC4181EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4182E0-PSG.edf
# ../../database\sleep-cassette\SC4182EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4191E0-PSG.edf
# ../../database\sleep-cassette\SC4191EP-Hypnogram.edf
# ../../database\sleep-cassette\SC4192E0-PSG.edf
# ../../database\sleep-cassette\SC4192EV-Hypnogram.edf
# ../../database\sleep-cassette\SC4201E0-PSG.edf
# ../../database\sleep-cassette\SC4201EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4202E0-PSG.edf
# ../../database\sleep-cassette\SC4202EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4211E0-PSG.edf
# ../../database\sleep-cassette\SC4211EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4212E0-PSG.edf
# ../../database\sleep-cassette\SC4212EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4221E0-PSG.edf
# ../../database\sleep-cassette\SC4221EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4222E0-PSG.edf
# ../../database\sleep-cassette\SC4222EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4231E0-PSG.edf
# ../../database\sleep-cassette\SC4231EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4232E0-PSG.edf
# ../../database\sleep-cassette\SC4232EV-Hypnogram.edf
# ../../database\sleep-cassette\SC4241E0-PSG.edf
# ../../database\sleep-cassette\SC4241EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4242E0-PSG.edf
# ../../database\sleep-cassette\SC4242EA-Hypnogram.edf
# ../../database\sleep-cassette\SC4251E0-PSG.edf
# ../../database\sleep-cassette\SC4251EP-Hypnogram.edf
# ../../database\sleep-cassette\SC4252E0-PSG.edf
# ../../database\sleep-cassette\SC4252EU-Hypnogram.edf
# ../../database\sleep-cassette\SC4261F0-PSG.edf
# ../../database\sleep-cassette\SC4261FM-Hypnogram.edf
# ../../database\sleep-cassette\SC4262F0-PSG.edf
# ../../database\sleep-cassette\SC4262FC-Hypnogram.edf
# ../../database\sleep-cassette\SC4271F0-PSG.edf
# ../../database\sleep-cassette\SC4271FC-Hypnogram.edf
# ../../database\sleep-cassette\SC4272F0-PSG.edf
# ../../database\sleep-cassette\SC4272FM-Hypnogram.edf
# ../../database\sleep-cassette\SC4281G0-PSG.edf
# ../../database\sleep-cassette\SC4281GC-Hypnogram.edf
# ../../database\sleep-cassette\SC4282G0-PSG.edf
# ../../database\sleep-cassette\SC4282GC-Hypnogram.edf
# ../../database\sleep-cassette\SC4291G0-PSG.edf
# ../../database\sleep-cassette\SC4291GA-Hypnogram.edf
# ../../database\sleep-cassette\SC4292G0-PSG.edf
# ../../database\sleep-cassette\SC4292GC-Hypnogram.edf
# ../../database\sleep-cassette\SC4301E0-PSG.edf
# ../../database\sleep-cassette\SC4301EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4302E0-PSG.edf
# ../../database\sleep-cassette\SC4302EV-Hypnogram.edf
# ../../database\sleep-cassette\SC4311E0-PSG.edf
# ../../database\sleep-cassette\SC4311EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4312E0-PSG.edf
# ../../database\sleep-cassette\SC4312EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4321E0-PSG.edf
# ../../database\sleep-cassette\SC4321EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4322E0-PSG.edf
# ../../database\sleep-cassette\SC4322EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4331F0-PSG.edf
# ../../database\sleep-cassette\SC4331FV-Hypnogram.edf
# ../../database\sleep-cassette\SC4332F0-PSG.edf
# ../../database\sleep-cassette\SC4332FC-Hypnogram.edf
# ../../database\sleep-cassette\SC4341F0-PSG.edf
# ../../database\sleep-cassette\SC4341FA-Hypnogram.edf
# ../../database\sleep-cassette\SC4342F0-PSG.edf
# ../../database\sleep-cassette\SC4342FA-Hypnogram.edf
# ../../database\sleep-cassette\SC4351F0-PSG.edf
# ../../database\sleep-cassette\SC4351FA-Hypnogram.edf
# ../../database\sleep-cassette\SC4352F0-PSG.edf
# ../../database\sleep-cassette\SC4352FV-Hypnogram.edf
# ../../database\sleep-cassette\SC4362F0-PSG.edf
# ../../database\sleep-cassette\SC4362FC-Hypnogram.edf
# ../../database\sleep-cassette\SC4371F0-PSG.edf
# ../../database\sleep-cassette\SC4371FA-Hypnogram.edf
# ../../database\sleep-cassette\SC4372F0-PSG.edf
# ../../database\sleep-cassette\SC4372FC-Hypnogram.edf
# ../../database\sleep-cassette\SC4381F0-PSG.edf
# ../../database\sleep-cassette\SC4381FC-Hypnogram.edf
# ../../database\sleep-cassette\SC4382F0-PSG.edf
# ../../database\sleep-cassette\SC4382FW-Hypnogram.edf
# ../../database\sleep-cassette\SC4401E0-PSG.edf
# ../../database\sleep-cassette\SC4401EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4402E0-PSG.edf
# ../../database\sleep-cassette\SC4402EW-Hypnogram.edf
# ../../database\sleep-cassette\SC4411E0-PSG.edf
# ../../database\sleep-cassette\SC4411EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4412E0-PSG.edf
# ../../database\sleep-cassette\SC4412EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4421E0-PSG.edf
# ../../database\sleep-cassette\SC4421EA-Hypnogram.edf
# ../../database\sleep-cassette\SC4422E0-PSG.edf
# ../../database\sleep-cassette\SC4422EA-Hypnogram.edf
# ../../database\sleep-cassette\SC4431E0-PSG.edf
# ../../database\sleep-cassette\SC4431EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4432E0-PSG.edf
# ../../database\sleep-cassette\SC4432EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4441E0-PSG.edf
# ../../database\sleep-cassette\SC4441EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4442E0-PSG.edf
# ../../database\sleep-cassette\SC4442EV-Hypnogram.edf
# ../../database\sleep-cassette\SC4451F0-PSG.edf
# ../../database\sleep-cassette\SC4451FY-Hypnogram.edf
# ../../database\sleep-cassette\SC4452F0-PSG.edf
# ../../database\sleep-cassette\SC4452FW-Hypnogram.edf
# ../../database\sleep-cassette\SC4461F0-PSG.edf
# ../../database\sleep-cassette\SC4461FA-Hypnogram.edf
# ../../database\sleep-cassette\SC4462F0-PSG.edf
# ../../database\sleep-cassette\SC4462FJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4471F0-PSG.edf
# ../../database\sleep-cassette\SC4471FA-Hypnogram.edf
# ../../database\sleep-cassette\SC4472F0-PSG.edf
# ../../database\sleep-cassette\SC4472FA-Hypnogram.edf
# ../../database\sleep-cassette\SC4481F0-PSG.edf
# ../../database\sleep-cassette\SC4481FV-Hypnogram.edf
# ../../database\sleep-cassette\SC4482F0-PSG.edf
# ../../database\sleep-cassette\SC4482FJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4491G0-PSG.edf
# ../../database\sleep-cassette\SC4491GJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4492G0-PSG.edf
# ../../database\sleep-cassette\SC4492GJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4501E0-PSG.edf
# ../../database\sleep-cassette\SC4501EW-Hypnogram.edf
# ../../database\sleep-cassette\SC4502E0-PSG.edf
# ../../database\sleep-cassette\SC4502EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4511E0-PSG.edf
# ../../database\sleep-cassette\SC4511EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4512E0-PSG.edf
# ../../database\sleep-cassette\SC4512EW-Hypnogram.edf
# ../../database\sleep-cassette\SC4522E0-PSG.edf
# ../../database\sleep-cassette\SC4522EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4531E0-PSG.edf
# ../../database\sleep-cassette\SC4531EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4532E0-PSG.edf
# ../../database\sleep-cassette\SC4532EV-Hypnogram.edf
# ../../database\sleep-cassette\SC4541F0-PSG.edf
# ../../database\sleep-cassette\SC4541FA-Hypnogram.edf
# ../../database\sleep-cassette\SC4542F0-PSG.edf
# ../../database\sleep-cassette\SC4542FW-Hypnogram.edf
# ../../database\sleep-cassette\SC4551F0-PSG.edf
# ../../database\sleep-cassette\SC4551FC-Hypnogram.edf
# ../../database\sleep-cassette\SC4552F0-PSG.edf
# ../../database\sleep-cassette\SC4552FW-Hypnogram.edf
# ../../database\sleep-cassette\SC4561F0-PSG.edf
# ../../database\sleep-cassette\SC4561FJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4562F0-PSG.edf
# ../../database\sleep-cassette\SC4562FJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4571F0-PSG.edf
# ../../database\sleep-cassette\SC4571FV-Hypnogram.edf
# ../../database\sleep-cassette\SC4572F0-PSG.edf
# ../../database\sleep-cassette\SC4572FC-Hypnogram.edf
# ../../database\sleep-cassette\SC4581G0-PSG.edf
# ../../database\sleep-cassette\SC4581GM-Hypnogram.edf
# ../../database\sleep-cassette\SC4582G0-PSG.edf
# ../../database\sleep-cassette\SC4582GP-Hypnogram.edf
# ../../database\sleep-cassette\SC4591G0-PSG.edf
# ../../database\sleep-cassette\SC4591GY-Hypnogram.edf
# ../../database\sleep-cassette\SC4592G0-PSG.edf
# ../../database\sleep-cassette\SC4592GY-Hypnogram.edf
# ../../database\sleep-cassette\SC4601E0-PSG.edf
# ../../database\sleep-cassette\SC4601EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4602E0-PSG.edf
# ../../database\sleep-cassette\SC4602EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4611E0-PSG.edf
# ../../database\sleep-cassette\SC4611EG-Hypnogram.edf
# ../../database\sleep-cassette\SC4612E0-PSG.edf
# ../../database\sleep-cassette\SC4612EA-Hypnogram.edf
# ../../database\sleep-cassette\SC4621E0-PSG.edf
# ../../database\sleep-cassette\SC4621EV-Hypnogram.edf
# ../../database\sleep-cassette\SC4622E0-PSG.edf
# ../../database\sleep-cassette\SC4622EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4631E0-PSG.edf
# ../../database\sleep-cassette\SC4631EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4632E0-PSG.edf
# ../../database\sleep-cassette\SC4632EA-Hypnogram.edf
# ../../database\sleep-cassette\SC4641E0-PSG.edf
# ../../database\sleep-cassette\SC4641EP-Hypnogram.edf
# ../../database\sleep-cassette\SC4642E0-PSG.edf
# ../../database\sleep-cassette\SC4642EP-Hypnogram.edf
# ../../database\sleep-cassette\SC4651E0-PSG.edf
# ../../database\sleep-cassette\SC4651EP-Hypnogram.edf
# ../../database\sleep-cassette\SC4652E0-PSG.edf
# ../../database\sleep-cassette\SC4652EG-Hypnogram.edf
# ../../database\sleep-cassette\SC4661E0-PSG.edf
# ../../database\sleep-cassette\SC4661EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4662E0-PSG.edf
# ../../database\sleep-cassette\SC4662EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4671G0-PSG.edf
# ../../database\sleep-cassette\SC4671GJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4672G0-PSG.edf
# ../../database\sleep-cassette\SC4672GV-Hypnogram.edf
# ../../database\sleep-cassette\SC4701E0-PSG.edf
# ../../database\sleep-cassette\SC4701EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4702E0-PSG.edf
# ../../database\sleep-cassette\SC4702EA-Hypnogram.edf
# ../../database\sleep-cassette\SC4711E0-PSG.edf
# ../../database\sleep-cassette\SC4711EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4712E0-PSG.edf
# ../../database\sleep-cassette\SC4712EA-Hypnogram.edf
# ../../database\sleep-cassette\SC4721E0-PSG.edf
# ../../database\sleep-cassette\SC4721EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4722E0-PSG.edf
# ../../database\sleep-cassette\SC4722EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4731E0-PSG.edf
# ../../database\sleep-cassette\SC4731EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4732E0-PSG.edf
# ../../database\sleep-cassette\SC4732EJ-Hypnogram.edf
# ../../database\sleep-cassette\SC4741E0-PSG.edf
# ../../database\sleep-cassette\SC4741EA-Hypnogram.edf
# ../../database\sleep-cassette\SC4742E0-PSG.edf
# ../../database\sleep-cassette\SC4742EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4751E0-PSG.edf
# ../../database\sleep-cassette\SC4751EC-Hypnogram.edf
# ../../database\sleep-cassette\SC4752E0-PSG.edf
# ../../database\sleep-cassette\SC4752EM-Hypnogram.edf
# ../../database\sleep-cassette\SC4761E0-PSG.edf
# ../../database\sleep-cassette\SC4761EP-Hypnogram.edf
# ../../database\sleep-cassette\SC4762E0-PSG.edf
# ../../database\sleep-cassette\SC4762EG-Hypnogram.edf
# ../../database\sleep-cassette\SC4771G0-PSG.edf
# ../../database\sleep-cassette\SC4771GC-Hypnogram.edf
# ../../database\sleep-cassette\SC4772G0-PSG.edf
# ../../database\sleep-cassette\SC4772GC-Hypnogram.edf
# ../../database\sleep-cassette\SC4801G0-PSG.edf
# ../../database\sleep-cassette\SC4801GC-Hypnogram.edf
# ../../database\sleep-cassette\SC4802G0-PSG.edf
# ../../database\sleep-cassette\SC4802GV-Hypnogram.edf
# ../../database\sleep-cassette\SC4811G0-PSG.edf
# ../../database\sleep-cassette\SC4811GG-Hypnogram.edf
# ../../database\sleep-cassette\SC4812G0-PSG.edf
# ../../database\sleep-cassette\SC4812GV-Hypnogram.edf
# ../../database\sleep-cassette\SC4821G0-PSG.edf
# ../../database\sleep-cassette\SC4821GC-Hypnogram.edf
# ../../database\sleep-cassette\SC4822G0-PSG.edf
# ../../database\sleep-cassette\SC4822GC-Hypnogram.edf
# ../../database\sleep-telemetry\ST7011J0-PSG.edf
# ../../database\sleep-telemetry\ST7011JP-Hypnogram.edf
# ../../database\sleep-telemetry\ST7012J0-PSG.edf
# ../../database\sleep-telemetry\ST7012JP-Hypnogram.edf
# ../../database\sleep-telemetry\ST7021J0-PSG.edf
# ../../database\sleep-telemetry\ST7021JM-Hypnogram.edf
# ../../database\sleep-telemetry\ST7022J0-PSG.edf
# ../../database\sleep-telemetry\ST7022JM-Hypnogram.edf
# ../../database\sleep-telemetry\ST7041J0-PSG.edf
# ../../database\sleep-telemetry\ST7041JO-Hypnogram.edf
# ../../database\sleep-telemetry\ST7042J0-PSG.edf
# ../../database\sleep-telemetry\ST7042JO-Hypnogram.edf
# ../../database\sleep-telemetry\ST7051J0-PSG.edf
# ../../database\sleep-telemetry\ST7051JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7052J0-PSG.edf
# ../../database\sleep-telemetry\ST7052JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7061J0-PSG.edf
# ../../database\sleep-telemetry\ST7061JR-Hypnogram.edf
# ../../database\sleep-telemetry\ST7062J0-PSG.edf
# ../../database\sleep-telemetry\ST7062JR-Hypnogram.edf
# ../../database\sleep-telemetry\ST7071J0-PSG.edf
# ../../database\sleep-telemetry\ST7071JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7072J0-PSG.edf
# ../../database\sleep-telemetry\ST7072JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7081J0-PSG.edf
# ../../database\sleep-telemetry\ST7081JW-Hypnogram.edf
# ../../database\sleep-telemetry\ST7082J0-PSG.edf
# ../../database\sleep-telemetry\ST7082JW-Hypnogram.edf
# ../../database\sleep-telemetry\ST7091J0-PSG.edf
# ../../database\sleep-telemetry\ST7091JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7092J0-PSG.edf
# ../../database\sleep-telemetry\ST7092JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7101J0-PSG.edf
# ../../database\sleep-telemetry\ST7101JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7102J0-PSG.edf
# ../../database\sleep-telemetry\ST7102JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7111J0-PSG.edf
# ../../database\sleep-telemetry\ST7111JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7112J0-PSG.edf
# ../../database\sleep-telemetry\ST7112JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7121J0-PSG.edf
# ../../database\sleep-telemetry\ST7121JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7122J0-PSG.edf
# ../../database\sleep-telemetry\ST7122JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7131J0-PSG.edf
# ../../database\sleep-telemetry\ST7131JR-Hypnogram.edf
# ../../database\sleep-telemetry\ST7132J0-PSG.edf
# ../../database\sleep-telemetry\ST7132JR-Hypnogram.edf
# ../../database\sleep-telemetry\ST7141J0-PSG.edf
# ../../database\sleep-telemetry\ST7141JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7142J0-PSG.edf
# ../../database\sleep-telemetry\ST7142JE-Hypnogram.edf
# ../../database\sleep-telemetry\ST7151J0-PSG.edf
# ../../database\sleep-telemetry\ST7151JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7152J0-PSG.edf
# ../../database\sleep-telemetry\ST7152JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7161J0-PSG.edf
# ../../database\sleep-telemetry\ST7161JM-Hypnogram.edf
# ../../database\sleep-telemetry\ST7162J0-PSG.edf
# ../../database\sleep-telemetry\ST7162JM-Hypnogram.edf
# ../../database\sleep-telemetry\ST7171J0-PSG.edf
# ../../database\sleep-telemetry\ST7171JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7172J0-PSG.edf
# ../../database\sleep-telemetry\ST7172JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7181J0-PSG.edf
# ../../database\sleep-telemetry\ST7181JR-Hypnogram.edf
# ../../database\sleep-telemetry\ST7182J0-PSG.edf
# ../../database\sleep-telemetry\ST7182JR-Hypnogram.edf
# ../../database\sleep-telemetry\ST7191J0-PSG.edf
# ../../database\sleep-telemetry\ST7191JR-Hypnogram.edf
# ../../database\sleep-telemetry\ST7192J0-PSG.edf
# ../../database\sleep-telemetry\ST7192JR-Hypnogram.edf
# ../../database\sleep-telemetry\ST7201J0-PSG.edf
# ../../database\sleep-telemetry\ST7201JO-Hypnogram.edf
# ../../database\sleep-telemetry\ST7202J0-PSG.edf
# ../../database\sleep-telemetry\ST7202JO-Hypnogram.edf
# ../../database\sleep-telemetry\ST7211J0-PSG.edf
# ../../database\sleep-telemetry\ST7211JJ-Hypnogram.edf
# ../../database\sleep-telemetry\ST7212J0-PSG.edf
# ../../database\sleep-telemetry\ST7212JJ-Hypnogram.edf
# ../../database\sleep-telemetry\ST7221J0-PSG.edf
# ../../database\sleep-telemetry\ST7221JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7222J0-PSG.edf
# ../../database\sleep-telemetry\ST7222JA-Hypnogram.edf
# ../../database\sleep-telemetry\ST7241J0-PSG.edf
# ../../database\sleep-telemetry\ST7241JO-Hypnogram.edf
# ../../database\sleep-telemetry\ST7242J0-PSG.edf
# ../../database\sleep-telemetry\ST7242JO-Hypnogram.edf

# %% [markdown]
# The next hidden code cells define functions for plotting data. Click on the "Code" button in the published kernel to reveal the hidden code.

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Oh, no! There are no automatic insights available for the file types used in this dataset. As your Kaggle kerneler bot, I'll keep working to fine-tune my hyper-parameters. In the meantime, please feel free to try a different dataset.

# %% [markdown]
# ## Conclusion
# This concludes your starter analysis! To go forward from here, click the blue "Fork Notebook" button at the top of this kernel. This will create a copy of the code and environment for you to edit. Delete, modify, and add code as you please. Happy Kaggling!
